# %%
from openpyxl import load_workbook

# %%
workbook=load_workbook(filename='file.xlsx')

# %%
Anime=workbook.active  #default workbook

# %%
value_in_B2=Anime.cell(row=3,column=3).value
print(value_in_B2)
# Out:
# None
