# %%
from openpyxl import load_workbook

# %%
workbook=load_workbook(filename='play.xlsx')

# %%
sheet=workbook.active

# %%
sheet.cell(row=2,column=3,value='MMA')
# Out:
# <Cell 'Sheet'.C2>

# %%
workbook.save('play.xlsx')

# %%
workbook.close()

# %% [raw]
# sheet['A2'].value= 'Test'   #to access
#
# or
#
# sheet['A2']= 'Test'    #to assign

# %%
book=load_workbook('file.xlsx')

# %%
shit=book.worksheets[0]
#or
#shit=book['Anime']

# %%
shit.cell(row=2,column=2,value='Kakarot')
# Out:
# <Cell 'Anime'.B2>

# %%
book.save('file.xlsx')

# %%
book.close()
