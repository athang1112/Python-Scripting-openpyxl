# %%
from openpyxl import load_workbook

# %%
workbook=load_workbook(filename='file.xlsx')

# %%
Anime=workbook.active

# %% [markdown]
# ### ROW

# %%
row_no=2 #i want data of only row2

# %%
for row in sheet1.iter_rows(min_row=row_no,max_row=row_no,min_col=1,max_col=4):
    #print(row)
    for cell in row:
        print(cell.value)
# Out:
# Goku
# None
# 30
# Saiyan Warrior

# %%
for row in sheet1.iter_rows(min_row=2,max_row=3,min_col=1,max_col=4):
    #print(row)
    print()
    for cell in row:
        print(cell.value)
# Out:
# Goku
# None
# 30
# Saiyan Warrior
#
# Naruto
# Uzumaki
# 12
# Hokage

# %% [markdown]
# ### COLUMN

# %%
col_no=2 #i want data of only column 2

# %%
for col in sheet1.iter_cols(min_col=2,max_col=2,min_row=1,max_row=4):
    #print(cell)
    for cell in col:
        print(cell.value)
# Out:
# None
# None
# Uzumaki
# Luffy

# %%
for col in sheet1.iter_cols(min_col=2,max_col=3,min_row=1,max_row=4):
    #print(cell)
    print()
    for cell in col:
        print(cell.value)
# Out:
# None
# None
# Uzumaki
# Luffy
#
# None
# 30
# 12
# 18

# %%
workbook.close()
