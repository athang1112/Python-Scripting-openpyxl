# %%
from openpyxl import Workbook

# %%
workbook=Workbook()

# %%
sheet=workbook.active

# %%
sheet.cell(row=2,column=2,value='Fight')
# Out:
# <Cell 'Sheet'.B2>

# %%
workbook.save('Play.xlsx')

# %%
workbook.close()
