# %%
from openpyxl import load_workbook

# %%
workbook=load_workbook(filename='file.xlsx')

# %%
sheet1=workbook['Anime']
sheet2=workbook['Cricketer']

# %%
print(sheet1.cell(row=2,column=2).value)
# Out:
# None

# %%
print(sheet2.cell(row=2,column=2).value)
# Out:
# Batsman

# %% [markdown]
# #### or

# %%
sheet_01=workbook.worksheets[0]
sheet_02=workbook.worksheets[1]

# %%
print(sheet_01.cell(row=2,column=2).value)
# Out:
# None

# %%
print(sheet_02.cell(row=2,column=2).value)
# Out:
# Batsman

# %%
workbook.create_sheet('Ani')
# Out:
# <Worksheet "Ani">

# %%
workbook.sheetnames
# Out:
# ['Anime', 'Cricketer', 'Ani']
